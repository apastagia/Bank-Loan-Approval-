# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import model_from_json

# %%
# load json and create model

sc = MinMaxScaler()

json_file = open('classifier.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
X = pd.read_csv('test.csv')
X
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           1.0             4583             1508.0      128000
# 1           0.0             3000                0.0       66000
# 2           0.0             2583             2358.0      120000
# 3           0.0             6000                0.0      141000
# 4           2.0             5417             4196.0      267000
# ..          ...              ...                ...         ...
# 475         0.0             2900                0.0       71000
# 476         3.0             4106                0.0       40000
# 477         1.0             8072              240.0      253000
# 478         2.0             7583                0.0      187000
# 479         0.0             4583                0.0      133000
#
#      Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 0               360.0             1.0              0            1           0
# 1               360.0             1.0              0            1           0
# 2               360.0             1.0              0            1           0
# 3               360.0             1.0              0            1           1
# 4               360.0             1.0              0            1           0
# ..                ...             ...            ...          ...         ...
# 475             360.0             1.0              1            0           1
# 476             180.0             1.0              0            1           0
# 477             360.0             1.0              0            1           0
# 478             360.0             1.0              0            1           0
# 479             360.0             0.0              1            0           1
#
#      Married_Yes  Education_Graduate  Education_Not Graduate  \
# 0              1                   1                       0
# 1              1                   1                       0
# 2              1                   0                       1
# 3              0                   1                       0
# 4              1                   1                       0
# ..           ...                 ...                     ...
# 475            0                   1                       0
# 476            1                   1                       0
# 477            1                   1                       0
# 478            1                   1                       0
# 479            0                   1                       0
#
#      Self_Employed_No  Self_Employed_Yes  Property_Area_Rural  \
# 0                   1                  0                    1
# 1                   0                  1                    0
# 2                   1                  0                    0
# 3                   1                  0                    0
# 4                   0                  1                    0
# ..                ...                ...                  ...
# 475                 1                  0                    1
# 476                 1                  0                    1
# 477                 1                  0                    0
# 478                 1                  0                    0
# 479                 0                  1                    0
#
#      Property_Area_Semiurban  Property_Area_Urban
# 0                          0                    0
# 1                          0                    1
# 2                          0                    1
# 3                          0                    1
# 4                          0                    1
# ..                       ...                  ...
# 475                        0                    0
# 476                        0                    0
# 477                        0                    1
# 478                        0                    1
# 479                        1                    0
#
# [480 rows x 17 columns]

# %%
X_test = sc.fit_transform(X)
X_test
# Out:
# array([[0.33333333, 0.05482993, 0.0445666 , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.03525046, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.03009276, 0.06968703, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.33333333, 0.09798392, 0.00709283, ..., 0.        , 0.        ,
#         1.        ],
#        [0.66666667, 0.09193568, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.05482993, 0.        , ..., 0.        , 1.        ,
#         0.        ]])
